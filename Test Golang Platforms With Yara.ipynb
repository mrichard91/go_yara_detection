# %%
import yara
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import matplotlib.pyplot as plt
import os
import re
import subprocess

SAMPLE_PATH = '/data/samples'
SIG_FILE = 'network_detect.yara'
SOURCE_FILE = 'network.go'

# %% [markdown]
# # Testing golang arch/platform compilation on Yara signature efficacy

# %%
# this calls the go binary to get all the supported architectures and platforms
# you should get 30-50 depending on version you are running
def get_arch_plat():
    p = subprocess.Popen (['go',  'tool', 'dist', 'list'], stdout=subprocess.PIPE)
    return [
        x.decode('utf-8').split('/')
        for x in p.stdout.read().split()
    ]
    
arch_plats = get_arch_plat()
print(f"Got {len(arch_plats)} plats")
# Out:
# Got 46 plats

# %%
# This loops over the available arch/plats and builds the local file network.go
# network.go contains a number of strings and identifiers that malware analysts would normally signature on

# GOARCH=arm64 go build -ldflags "-s -w" -o test.exe network.go  
for (plat, arch) in arch_plats:
    filename = f"network_{plat}_{arch}.out"
    print(f"making {filename}")
    myenv = os.environ.copy()
    myenv['GOOS'] = plat
    myenv['GOARCH'] = arch
    p = subprocess.run(
        ['go', 'build', '-ldflags=-buildid=', '-o', f"/data/samples/{filename}", f"/data/{SOURCE_FILE}"],
        env=myenv,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
    )
    #print(p.stderr)
# Out:
# making network_aix_ppc64.out
# making network_android_386.out
# making network_android_amd64.out
# making network_android_arm.out
# making network_android_arm64.out
# making network_darwin_amd64.out
# making network_darwin_arm64.out
# making network_dragonfly_amd64.out
# making network_freebsd_386.out
# making network_freebsd_amd64.out
# making network_freebsd_arm.out
# making network_freebsd_arm64.out
# making network_illumos_amd64.out
# making network_ios_amd64.out
# making network_ios_arm64.out
# making network_js_wasm.out
# making network_linux_386.out
# making network_linux_amd64.out
# making network_linux_arm.out
# making network_linux_arm64.out
# making network_linux_loong64.out
# making network_linux_mips.out
# making network_linux_mips64.out
# making network_linux_mips64le.out
# making network_linux_mipsle.out
# making network_linux_ppc64.out
# making network_linux_ppc64le.out
# making network_linux_riscv64.out
# making network_linux_s390x.out
# making network_netbsd_386.out
# making network_netbsd_amd64.out
# making network_netbsd_arm.out
# making network_netbsd_arm64.out
# making network_openbsd_386.out
# making network_openbsd_amd64.out
# making network_openbsd_arm.out
# making network_openbsd_arm64.out
# making network_openbsd_mips64.out
# making network_plan9_386.out
# making network_plan9_amd64.out
# making network_plan9_arm.out
# making network_solaris_amd64.out
# making network_windows_386.out
# making network_windows_amd64.out
# making network_windows_arm.out
# making network_windows_arm64.out

# %%
# Here we go through every file, run yara and capture a dictionary of results for later analysis

filename_parser = re.compile(r'network\_(\w+)\_(\w+)\..+', re.S)

def process_file(yara, filename):
    m = filename_parser.match(filename)
    arch = m.group(2)
    plat = m.group(1)
    return {
        'filename': filename,
        'yara': y.match(f"{SAMPLE_PATH}/{filename}"),
        'os': plat,
        'arch': arch,
    }     

y = yara.compile(SIG_FILE)
files = os.listdir(SAMPLE_PATH)
print(f"Found {len(files)} samples to scan")

# then convert the results to a dataframe for easier viewing and analysis
df = pd.DataFrame([
    process_file(y, x)
    for x in files
])
df.head()
# Out:
# Found 41 samples to scan
#                     filename  \
# 0  network_linux_riscv64.out
# 1  network_linux_loong64.out
# 2  network_android_arm64.out
# 3  network_illumos_amd64.out
# 4   network_darwin_amd64.out
#
#                                                 yara       os     arch
# 0  [network_detect_partial_GET, network_detect_fu...    linux  riscv64
# 1  [network_detect_partial_GET, network_detect_fu...    linux  loong64
# 2  [network_detect_partial_GET, network_detect_fu...  android    arm64
# 3  [network_detect_partial_GET, network_detect_c2...  illumos    amd64
# 4  [network_detect_partial_GET, network_detect_c2...   darwin    amd64

# %%
# here we take each detection from the yara column and one-hot encode them to easily tell
# which strings are detected and which are not
mlb = MultiLabelBinarizer(sparse_output=True)

# let's one-hot encode the yara column for easier analysis
df = df.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df.pop('yara')),
                index=df.index,
                columns=mlb.classes_))

# %%
# helper functions for pretty printing results
# colors the cells diff colors based on detection
def yara_detection(v):
    if v == 1:
        return "Detected"
    if v == 0:
        return "Not Detected"
    return v

def make_pretty(styler):
    styler.set_caption("Yara Detection Matrix")
    styler.format(yara_detection)
    styler.background_gradient(axis=None, vmin=0, vmax=1, cmap="YlGnBu")
    return styler

df.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# #T_0f570_row0_col3, #T_0f570_row0_col4, #T_0f570_row0_col5, #T_0f570_row0_col6, #T_0f570_row0_col7, #T_0f570_row0_col10, #T_0f570_row1_col3, #T_0f570_row1_col4, #T_0f570_row1_col5, #T_0f570_row1_col6, #T_0f570_row1_col7, #T_0f570_row1_col10, #T_0f570_row2_col3, #T_0f570_row2_col4, #T_0f570_row2_col5, #T_0f570_row2_col6, #T_0f570_row2_col7, #T_0f570_row2_col10, #T_0f570_row3_col3, #T_0f570_row3_col4, #T_0f570_row3_col5, #T_0f570_row3_col6, #T_0f570_row3_col9, #T_0f570_row3_col10, #T_0f570_row4_col3, #T_0f570_row4_col4, #T_0f570_row4_col5, #T_0f570_row4_col6, #T_0f570_row4_col9, #T_0f570_row4_col10, #T_0f570_row5_col3, #T_0f570_row5_col4, #T_0f570_row5_col5, #T_0f570_row5_col6, #T_0f570_row5_col7, #T_0f570_row5_col9, #T_0f570_row5_col10, #T_0f570_row6_col3, #T_0f570_row6_col4, #T_0f570_row6_col5, #T_0f570_row6_col6, #T_0f570_row6_col7, #T_0f570_row6_col9, #T_0f570_row6_col10, #T_0f570_row7_col3, #T_0f570_row7_col4, #T_0f570_row7_col5, #T_0f570_row7_col6, #T_0f570_row7_col7, #T_0f570_row7_col10, #T_0f570_row8_col3, #T_0f570_row8_col4, #T_0f570_row8_col5, #T_0f570_row8_col6, #T_0f570_row8_col7, #T_0f570_row8_col9, #T_0f570_row8_col10, #T_0f570_row9_col3, #T_0f570_row9_col4, #T_0f570_row9_col5, #T_0f570_row9_col6, #T_0f570_row9_col7, #T_0f570_row9_col9, #T_0f570_row9_col10, #T_0f570_row10_col3, #T_0f570_row10_col4, #T_0f570_row10_col5, #T_0f570_row10_col6, #T_0f570_row10_col7, #T_0f570_row10_col9, #T_0f570_row10_col10, #T_0f570_row11_col3, #T
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_0f570_row0_col8, #T_0f570_row0_col9, #T_0f570_row1_col8, #T_0f570_row1_col9, #T_0f570_row2_col8, #T_0f570_row2_col9, #T_0f570_row3_col7, #T_0f570_row3_col8, #T_0f570_row4_col7, #T_0f570_row4_col8, #T_0f570_row5_col8, #T_0f570_row6_col8, #T_0f570_row7_col8, #T_0f570_row7_col9, #T_0f570_row8_col8, #T_0f570_row9_col8, #T_0f570_row10_col8, #T_0f570_row11_col8, #T_0f570_row11_col9, #T_0f570_row12_col8, #T_0f570_row12_col9, #T_0f570_row13_col8, #T_0f570_row13_col9, #T_0f570_row14_col7, #T_0f570_row14_col8, #T_0f570_row14_col9, #T_0f570_row14_col10, #T_0f570_row15_col8, #T_0f570_row15_col9, #T_0f570_row16_col8, #T_0f570_row16_col9, #T_0f570_row17_col8, #T_0f570_row17_col9, #T_0f570_row18_col7, #T_0f570_row18_col8, #T_0f570_row19_col7, #T_0f570_row19_col8, #T_0f570_row19_col9, #T_0f570_row19_col10, #T_0f570_row20_col8, #T_0f570_row20_col9, #T_0f570_row21_col8, #T_0f570_row21_col9, #T_0f570_row22_col8, #T_0f570_row22_col9, #T_0f570_row23_col7, #T_0f570_row23_col8, #T_0f570_row23_col9, #T_0f570_row23_col10, #T_0f570_row24_col7, #T_0f570_row24_col8, #T_0f570_row25_col7, #T_0f570_row25_col8, #T_0f570_row25_col9, #T_0f570_row25_col10, #T_0f570_row26_col8, #T_0f570_row27_col8, #T_0f570_row27_col9, #T_0f570_row28_col7, #T_0f570_row28_col8, #T_0f570_row29_col8, #T_0f570_row29_col9, #T_0f570_row30_col8, #T_0f570_row30_col9, #T_0f570_row31_col7, #T_0f570_row31_col8, #T_0f570_row31_col9, #T_0f570_row31_col10, #T_0f570_row32_col7, #T_0f570_row32_col8, #T_0f570_row33_col7, #T_0f570_row33_col8, #T_0f570_row34_col8, #T_0f570_row34_col9, #T_0f570_row35_col7, #T_0f570_row35_col8, #T_0f570_row36_col7, #T_0f570_row36_col8, #T_0f570_row36_col9, #T_0f570_row36_col10, #T_0f570_row37_col8, #T_0f570_row37_col9, #T_0f570_row38_col7, #T_0f570_row38_col8, #T_0f570_row39_col7, #T_0f570_row39_col8 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_0f570">
#   <caption>Yara Detection Matrix</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f570_level0_col0" class="col_heading level0 col0" >filename</th>
#       <th id="T_0f570_level0_col1" class="col_heading level0 col1" >os</th>
#       <th id="T_0f570_level0_col2" class="col_heading level0 col2" >arch</th>
#       <th id="T_0f570_level0_col3" class="col_heading level0 col3" >detect_go_binary_buildid</th>
#       <th id="T_0f570_level0_col4" class="col_heading level0 col4" >network_detect_c2_domain</th>
#       <th id="T_0f570_level0_col5" class="col_heading level0 col5" >network_detect_c2_ipv6</th>
#       <th id="T_0f570_level0_col6" class="col_heading level0 col6" >network_detect_error_message_string</th>
#       <th id="T_0f570_level0_col7" class="col_heading level0 col7" >network_detect_full_GET</th>
#       <th id="T_0f570_level0_col8" class="col_heading level0 col8" >network_detect_full_GET_fullword</th>
#       <th id="T_0f570_level0_col9" class="col_headi

# %%
# finally we can do some manual "hunting" for the magic string that is only detected on x86
# we can see from the output here that for arm/risc/ppc the value is little endian, and for x86 it's big endian

for file in files:
    with open(f"{SAMPLE_PATH}/{file}", "rb") as f:
        data = f.read()
    if data.find(b'\x19\x80\x14\x06') > 0:
        print(f"Found big endian magic in {file}")
    if data.find(b'\x06\x14\x80\x19') > 0 or data.find(b'\x14\x06\x19\x80'): # byte and word swap'd for arch
        print(f"Found little endian magic in {file}")
# Out:
# Found little endian magic in network_linux_riscv64.out
# Found little endian magic in network_linux_loong64.out
# Found little endian magic in network_android_arm64.out
# Found big endian magic in network_illumos_amd64.out
# Found little endian magic in network_illumos_amd64.out
# Found big endian magic in network_darwin_amd64.out
# Found little endian magic in network_darwin_amd64.out
# Found big endian magic in network_windows_386.out
# Found little endian magic in network_windows_386.out
# Found big endian magic in network_freebsd_386.out
# Found little endian magic in network_freebsd_386.out
# Found little endian magic in network_aix_ppc64.out
# Found big endian magic in network_plan9_386.out
# Found little endian magic in network_plan9_386.out
# Found big endian magic in network_openbsd_386.out
# Found little endian magic in network_openbsd_386.out
# Found big endian magic in network_netbsd_386.out
# Found little endian magic in network_netbsd_386.out
# Found little endian magic in network_openbsd_mips64.out
# Found little endian magic in network_darwin_arm64.out
# Found little endian magic in network_linux_arm.out
# Found little endian magic in network_js_wasm.out
# Found little endian magic in network_linux_ppc64.out
# Found little endian magic in network_linux_mipsle.out
# Found little endian magic in network_plan9_arm.out
# Found big endian magic in network_openbsd_amd64.out
# Found little endian magic in network_openbsd_amd64.out
# Found little endian magic in network_linux_arm64.out
# Found little endian magic in network_netbsd_arm.out
# Found little endian magic in network_openbsd_arm.out
# Found little endian magic in network_linux_mips64.out
# Found little endian magic in network_netbsd_arm64.out
# Found big endian magic in network_windows_amd64.out
# Found little endian magic in network_windows_amd64.out
# Found little endian magic in network_freebsd_arm64.out
# Found big endian magic in network_linux_386.out
# Found little endian magic in network_linux_386.out
# Found little endian magic in network_linux_mips64le.out
# Found big endian magic in network_linux_amd64.out
# Found little endian magic in network_linux_amd64.out
# Found little endian magic in network_linux_ppc64le.out
# Found little endian magic in network_linux_mips.out
# Found little endian magic in network_openbsd_arm64.out
# Found big endian magic in network_plan9_amd64.out
# Found little endian magic in network_plan9_amd64.out
# Found big endian magic in network_freebsd_amd64.out
# Found little endian magic in network_freebsd_amd64.out
# Found little endian magic in network_windows_arm.out
# Found big endian magic in network_solaris_amd64.out
# Found little endian magic in network_solaris_amd64.out
# Found little endian magic in network_windows_arm64.out
# Found little endian magic in network_freebsd_arm.out
# Found big endian magic in network_netbsd_amd64.out
# Found little endian magic in network_netbsd_amd64.out
# Found big endian magic in network_dragonfly_amd64.out
# Found little endian magic in network_dragonfly_amd64.out
# Found big endian magic in network_linux_s390x.out
# Found little endian magic in network_linux_s390x.out
